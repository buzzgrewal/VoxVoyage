# %%
# !apt update && apt install -y espeak-ng

# !pip install -U uv

# !git clone https://github.com/Zyphra/Zonos.git
# %cd Zonos

# !uv sync
# !uv sync --extra compile
# Out:
# Streaming output truncated to the last 5000 lines.
# nvidia-cublas-cu12 ------------------------------ 177.42 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 177.11 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (99/108)
# gradio     ------------------------------ 52.24 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 177.40 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 175.51 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 172.90 MiB/201.66 MiB
# triton     ------------------------------ 177.36 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 177.74 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 177.51 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (99/108)
# gradio     ------------------------------ 52.24 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 177.82 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 175.51 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 173.31 MiB/201.66 MiB
# triton     ------------------------------ 177.78 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 178.18 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 177.85 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (99/108)
# gradio     ------------------------------ 52.71 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 178.05 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 175.81 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 173.31 MiB/201.66 MiB
# triton     ------------------------------ 177.78 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 178.43 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 177.85 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (99/108)
# gradio     ------------------------------ 52.71 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 178.05 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 176.28 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 173.83 MiB/201.66 MiB
# triton     ------------------------------ 178.28 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 178.69 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 178.33 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (99/108)
# gradio     ------------------------------ 52.71 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 178.08 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 176.73 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 173.89 MiB/201.66 MiB
# triton     ------------------------------ 178.34 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 179.17 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 178.36 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (99/108)
# gradio     ------------------------------ 52.71 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 178.56 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 176.81 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 174.04 MiB/201.66 MiB
# triton     ------------------------------ 178.78 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 179.17 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 178.78 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (99/108)
# gradio     ------------------------------ 52.71 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 178.62 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 177.30 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 174.42 MiB/201.66 MiB
# triton     ------------------------------ 179.04 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 179.22 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 178.91 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (99/108)
# gradio     ------------------------------ 52.71 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 178.62 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 177.30 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 174.42 MiB/201.66 MiB
# triton     ------------------------------ 179.22 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 179.30 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 179.25 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (99/108)
# gradio     ------------------------------ 52.74 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 179.08 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 177.30 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 174.46 MiB/201.66 MiB
# triton     ------------------------------ 179.25 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 179.66 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 179.25 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (99/108)
# gradio     ------------------------------ 52.74 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 179.08 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 177.74 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 174.82 MiB/201.66 MiB
# triton     ------------------------------ 179.27 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 180.00 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 179.30 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (99/108)
# gradio     ------------------------------ 52.79 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 179.48 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 177.78 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 174.82 MiB/201.66 MiB
# triton     ------------------------------ 179.69 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 180.08 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 179.68 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (99/108)
# gradio     ------------------------------ 52.83 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 179.51 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 177.78 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 174.86 MiB/201.66 MiB
# triton     ------------------------------ 180.06 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 180.51 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 179.75 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (99/108)
# gradio     ------------------------------ 52.83 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 179.91 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 178.09 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 174.86 MiB/201.66 MiB
# triton     ------------------------------ 180.11 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 180.51 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 180.06 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (99/108)
# gradio     ------------------------------ 52.91 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 179.91 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 178.21 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 175.32 MiB/201.66 MiB
# triton     ------------------------------ 180.16 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 180.56 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 180.11 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (99/108)
# gradio     ------------------------------ 52.91 MiB/55.09 MiB
# nvidia-nccl-cu12 ------------------------------ 179.91 MiB/179.91 MiB
# nvidia-cusparse-cu12 ------------------------------ 178.21 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 175.73 MiB/201.66 MiB
# triton     ------------------------------ 180.59 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 180.59 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 180.11 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (99/108)
# gradio     ------------------------------ 52.94 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 178.63 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 175.73 MiB/201.66 MiB
# triton     ------------------------------ 180.59 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 181.00 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 180.56 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (99/108)
# gradio     ------------------------------ 52.99 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 178.70 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 175.85 MiB/201.66 MiB
# triton     ------------------------------ 180.66 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 181.06 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 180.59 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (99/108)
# gradio     ------------------------------ 52.99 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 178.76 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 176.27 MiB/201.66 MiB
# triton     ------------------------------ 181.06 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 181.06 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 181.05 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (99/108)
# gradio     ------------------------------ 52.99 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 178.96 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 176.27 MiB/201.66 MiB
# triton     ------------------------------ 181.06 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 181.45 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 181.05 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (99/108)
# gradio     ------------------------------ 53.01 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 179.05 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 176.37 MiB/201.66 MiB
# triton     ------------------------------ 181.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 181.57 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 181.55 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠦ Preparing packages... (100/108)
# gradio     ------------------------------ 53.01 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 179.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 176.37 MiB/201.66 MiB
# triton     ------------------------------ 181.58 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 181.96 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 181.55 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠦ Preparing packages... (100/108)
# gradio     ------------------------------ 53.01 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 179.58 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 176.97 MiB/201.66 MiB
# triton     ------------------------------ 181.69 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 182.03 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 181.58 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠦ Preparing packages... (100/108)
# gradio     ------------------------------ 53.01 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 180.06 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 177.12 MiB/201.66 MiB
# triton     ------------------------------ 181.69 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 182.03 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 182.00 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠦ Preparing packages... (100/108)
# gradio     ------------------------------ 53.01 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 180.06 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 177.12 MiB/201.66 MiB
# triton     ------------------------------ 181.70 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 182.50 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 182.03 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠧ Preparing packages... (100/108)
# gradio     ------------------------------ 53.01 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 180.06 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 177.12 MiB/201.66 MiB
# triton     ------------------------------ 182.09 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 182.50 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 182.38 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠧ Preparing packages... (100/108)
# gradio     ------------------------------ 53.01 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 180.06 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 177.65 MiB/201.66 MiB
# triton     ------------------------------ 182.34 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 182.97 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 182.53 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠧ Preparing packages... (100/108)
# gradio     ------------------------------ 53.02 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 180.58 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 177.65 MiB/201.66 MiB
# triton     ------------------------------ 182.66 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 182.97 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 182.68 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠧ Preparing packages... (100/108)
# gradio     ------------------------------ 53.02 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 180.58 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 177.65 MiB/201.66 MiB
# triton     ------------------------------ 182.66 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 183.06 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 183.00 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠇ Preparing packages... (100/108)
# gradio     ------------------------------ 53.02 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 180.99 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 177.93 MiB/201.66 MiB
# triton     ------------------------------ 182.66 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 183.64 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 183.00 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠇ Preparing packages... (100/108)
# gradio     ------------------------------ 53.16 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 180.99 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 178.19 MiB/201.66 MiB
# triton     ------------------------------ 183.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 183.65 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 183.00 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠇ Preparing packages... (100/108)
# gradio     ------------------------------ 53.16 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 181.49 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 178.49 MiB/201.66 MiB
# triton     ------------------------------ 183.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 183.65 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 183.51 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠇ Preparing packages... (100/108)
# gradio     ------------------------------ 53.16 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 181.49 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 178.49 MiB/201.66 MiB
# triton     ------------------------------ 183.67 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 183.90 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 183.51 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠋ Preparing packages... (100/108)
# gradio     ------------------------------ 53.17 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 181.51 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 178.49 MiB/201.66 MiB
# triton     ------------------------------ 183.70 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 184.63 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 183.53 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠋ Preparing packages... (100/108)
# gradio     ------------------------------ 53.17 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 182.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 178.98 MiB/201.66 MiB
# triton     ------------------------------ 184.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 184.63 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 183.54 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠋ Preparing packages... (100/108)
# gradio     ------------------------------ 53.19 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 182.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 178.98 MiB/201.66 MiB
# triton     ------------------------------ 184.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 184.63 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 184.05 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠋ Preparing packages... (100/108)
# gradio     ------------------------------ 53.19 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 182.47 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 178.98 MiB/201.66 MiB
# triton     ------------------------------ 184.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 184.63 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 184.05 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (100/108)
# gradio     ------------------------------ 53.19 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 182.47 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 178.98 MiB/201.66 MiB
# triton     ------------------------------ 184.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 185.19 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 184.40 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (100/108)
# gradio     ------------------------------ 53.19 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 182.47 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 179.50 MiB/201.66 MiB
# triton     ------------------------------ 184.75 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 185.19 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 184.57 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (100/108)
# gradio     ------------------------------ 53.68 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 182.48 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 179.50 MiB/201.66 MiB
# triton     ------------------------------ 184.75 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 185.19 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 184.57 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (100/108)
# gradio     ------------------------------ 54.30 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 182.48 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 179.50 MiB/201.66 MiB
# triton     ------------------------------ 184.75 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 185.41 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 184.57 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (100/108)
# gradio     ------------------------------ 54.30 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 182.48 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.00 MiB/201.66 MiB
# triton     ------------------------------ 184.77 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 185.67 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 185.03 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (100/108)
# gradio     ------------------------------ 54.30 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 182.76 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.00 MiB/201.66 MiB
# triton     ------------------------------ 185.31 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 185.67 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 185.03 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (100/108)
# gradio     ------------------------------ 54.39 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 183.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.00 MiB/201.66 MiB
# triton     ------------------------------ 185.31 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 185.87 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 185.26 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (100/108)
# gradio     ------------------------------ 54.39 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 183.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.72 MiB/201.66 MiB
# triton     ------------------------------ 185.50 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 185.89 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 185.26 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (100/108)
# gradio     ------------------------------ 54.39 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 183.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.72 MiB/201.66 MiB
# triton     ------------------------------ 185.50 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 186.42 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 185.65 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (100/108)
# gradio     ------------------------------ 54.39 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 183.69 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.72 MiB/201.66 MiB
# triton     ------------------------------ 185.50 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 186.42 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 185.75 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (100/108)
# gradio     ------------------------------ 54.39 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 183.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.72 MiB/201.66 MiB
# triton     ------------------------------ 185.96 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 186.42 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 185.96 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (100/108)
# gradio     ------------------------------ 54.44 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 183.89 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.90 MiB/201.66 MiB
# triton     ------------------------------ 186.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 186.61 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 185.96 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (100/108)
# gradio     ------------------------------ 54.44 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 184.37 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.90 MiB/201.66 MiB
# triton     ------------------------------ 186.34 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 186.61 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 185.96 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (100/108)
# gradio     ------------------------------ 54.44 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 184.37 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 180.90 MiB/201.66 MiB
# triton     ------------------------------ 186.77 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 187.06 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 186.51 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (100/108)
# gradio     ------------------------------ 54.50 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 184.37 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 181.37 MiB/201.66 MiB
# triton     ------------------------------ 186.77 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 187.22 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 186.51 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (100/108)
# gradio     ------------------------------ 54.50 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 184.37 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 181.37 MiB/201.66 MiB
# triton     ------------------------------ 186.77 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 187.95 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 186.81 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (100/108)
# gradio     ------------------------------ 54.50 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 181.37 MiB/201.66 MiB
# triton     ------------------------------ 186.77 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 187.95 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 187.12 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (100/108)
# gradio     ------------------------------ 54.50 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 181.37 MiB/201.66 MiB
# triton     ------------------------------ 187.25 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 187.95 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 187.12 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (100/108)
# gradio     ------------------------------ 54.56 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 182.00 MiB/201.66 MiB
# triton     ------------------------------ 187.52 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 187.95 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 187.12 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (100/108)
# gradio     ------------------------------ 54.56 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 182.00 MiB/201.66 MiB
# triton     ------------------------------ 187.52 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 187.95 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 187.12 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠦ Preparing packages... (100/108)
# gradio     ------------------------------ 54.56 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 182.00 MiB/201.66 MiB
# triton     ------------------------------ 188.30 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 187.95 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 187.71 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠦ Preparing packages... (100/108)
# gradio     ------------------------------ 54.56 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.42 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 182.00 MiB/201.66 MiB
# triton     ------------------------------ 188.30 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 188.63 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 187.88 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠦ Preparing packages... (100/108)
# gradio     ------------------------------ 54.58 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 182.67 MiB/201.66 MiB
# triton     ------------------------------ 188.34 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 188.63 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 187.88 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠦ Preparing packages... (100/108)
# gradio     ------------------------------ 54.58 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 182.67 MiB/201.66 MiB
# triton     ------------------------------ 188.34 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 189.14 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 187.88 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠧ Preparing packages... (100/108)
# gradio     ------------------------------ 54.58 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 183.51 MiB/201.66 MiB
# triton     ------------------------------ 188.34 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 189.25 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 187.90 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠧ Preparing packages... (100/108)
# gradio     ------------------------------ 54.58 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 183.51 MiB/201.66 MiB
# triton     ------------------------------ 188.34 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 189.25 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 188.42 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠧ Preparing packages... (100/108)
# gradio     ------------------------------ 54.58 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 183.51 MiB/201.66 MiB
# triton     ------------------------------ 188.34 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 189.25 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 188.68 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠧ Preparing packages... (100/108)
# gradio     ------------------------------ 54.58 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 185.87 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 183.51 MiB/201.66 MiB
# triton     ------------------------------ 189.14 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 189.25 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 188.68 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠇ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 186.31 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 183.51 MiB/201.66 MiB
# triton     ------------------------------ 189.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 189.33 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 188.69 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠇ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 186.31 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 184.09 MiB/201.66 MiB
# triton     ------------------------------ 189.19 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 189.96 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 188.69 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠇ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 187.03 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 184.18 MiB/201.66 MiB
# triton     ------------------------------ 189.95 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 189.96 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 189.42 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠇ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 187.03 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 184.20 MiB/201.66 MiB
# triton     ------------------------------ 190.02 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 190.57 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 189.47 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠋ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 187.82 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 184.22 MiB/201.66 MiB
# triton     ------------------------------ 190.02 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 190.76 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 189.47 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠋ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 187.82 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 184.98 MiB/201.66 MiB
# triton     ------------------------------ 190.02 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 190.76 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 190.00 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠋ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 187.82 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 184.98 MiB/201.66 MiB
# triton     ------------------------------ 190.28 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 190.76 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 190.06 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠋ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 187.90 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 184.99 MiB/201.66 MiB
# triton     ------------------------------ 190.81 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 190.78 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 190.70 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 188.09 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 184.99 MiB/201.66 MiB
# triton     ------------------------------ 190.81 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 191.23 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 190.70 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 188.09 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 185.56 MiB/201.66 MiB
# triton     ------------------------------ 191.48 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 191.23 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 190.70 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 188.33 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 185.78 MiB/201.66 MiB
# triton     ------------------------------ 191.70 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 191.45 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 190.90 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠙ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 188.33 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 185.78 MiB/201.66 MiB
# triton     ------------------------------ 192.23 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 192.00 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 190.95 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 188.92 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 185.87 MiB/201.66 MiB
# triton     ------------------------------ 192.23 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 192.00 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 191.31 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 188.92 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 186.38 MiB/201.66 MiB
# triton     ------------------------------ 192.23 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 192.00 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 191.31 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 189.10 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 186.57 MiB/201.66 MiB
# triton     ------------------------------ 192.42 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 192.22 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 191.31 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠹ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 189.70 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.00 MiB/201.66 MiB
# triton     ------------------------------ 192.42 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 192.22 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 191.53 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 189.70 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.00 MiB/201.66 MiB
# triton     ------------------------------ 192.42 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 192.22 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 191.91 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 189.70 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.00 MiB/201.66 MiB
# triton     ------------------------------ 192.78 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 192.82 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 192.06 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 189.92 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.00 MiB/201.66 MiB
# triton     ------------------------------ 193.17 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 193.00 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 192.23 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠸ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 189.92 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.20 MiB/201.66 MiB
# triton     ------------------------------ 193.17 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 193.00 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 192.86 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 190.25 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.86 MiB/201.66 MiB
# triton     ------------------------------ 193.17 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 193.00 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 192.91 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (100/108)
# gradio     ------------------------------ 54.59 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 190.25 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.86 MiB/201.66 MiB
# triton     ------------------------------ 193.92 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 193.18 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 192.91 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (100/108)
# gradio     ------------------------------ 54.74 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 190.25 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.86 MiB/201.66 MiB
# triton     ------------------------------ 193.92 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 193.69 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 192.91 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠼ Preparing packages... (100/108)
# gradio     ------------------------------ 54.74 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 190.25 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.86 MiB/201.66 MiB
# triton     ------------------------------ 193.92 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 194.25 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 192.91 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (100/108)
# gradio     ------------------------------ 54.74 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 190.25 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 187.86 MiB/201.66 MiB
# triton     ------------------------------ 194.56 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 194.25 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 193.67 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (100/108)
# gradio     ------------------------------ 54.74 MiB/55.09 MiB
# nvidia-cusparse-cu12 ------------------------------ 191.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 188.23 MiB/201.66 MiB
# triton     ------------------------------ 194.56 MiB/241.43 MiB
# nvidia-cublas-cu12 ------------------------------ 194.25 MiB/346.60 MiB
# nvidia-cudnn-cu12 ------------------------------ 193.68 MiB/633.96 MiB
#    Building sudachidict-full==20250129
#       Built pylatexenc==2.10
# ⠴ Preparing packages... (100/108)
# nvidia-cusparse-cu12 ------------------------------ 191.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 188.60 MiB/201.66 MiB
# triton     ------------------------------ 194.56 MiB/241.43 MiB
# ...
# ⠇ Preparing packages... (107/108)
# ⠇ Preparing packages... (107/108)
# ⠋ Preparing packages... (107/108)
# ⠋ Preparing packages... (107/108)
# Prepared 108 packages in 2m 11s
# Installed 108 packages in 834ms
#  + aiofiles==23.2.1
#  + annotated-types==0.7.0
#  + anyio==4.8.0
#  + attrs==25.1.0
#  + babel==2.17.0
#  + certifi==2025.1.31
#  + cffi==1.17.1
#  + charset-normalizer==3.4.1
#  + click==8.1.8
#  + clldutils==3.21.0
#  + colorama==0.4.6
#  + colorlog==6.9.0
#  + csvw==3.5.1
#  + dlinfo==2.0.0
#  + fastapi==0.115.8
#  + ffmpy==0.5.0
#  + filelock==3.17.0
#  + fsspec==2025.2.0
#  + gradio==5.15.0
#  + gradio-client==1.7.0
#  + h11==0.14.0
#  + httpcore==1.0.7
#  + httpx==0.28.1
#  + huggingface-hub==0.28.1
#  + idna==3.10
#  + inflect==7.5.0
#  + isodate==0.7.2
#  + jinja2==3.1.5
#  + joblib==1.4.2
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kanjize==1.5.0
#  + language-tags==1.2.0
#  + lxml==5.3.0
#  + markdown==3.7
#  + markdown-it-py==3.0.0
#  + markupsafe==2.1.5
#  + mdurl==0.1.2
#  + more-itertools==10.6.0
#  + mpmath==1.3.0
#  + networkx==3.4.2
#  + numpy==2.2.2
#  + nvidia-cublas-cu12==12.4.5.8
#  + nvidia-cuda-cupti-cu12==12.4.127
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  + nvidia-cuda-runtime-cu12==12.4.127
#  + nvidia-cudnn-cu12==9.1.0.70
#  + nvidia-cufft-cu12==11.2.1.3
#  + nvidia-curand-cu12==10.3.5.147
#  + nvidia-cusolver-cu12==11.6.1.9
#  + nvidia-cusparse-cu12==12.3.1.170
#  + nvidia-cusparselt-cu12==0.6.2
#  + nvidia-nccl-cu12==2.21.5
#  + nvidia-nvjitlink-cu12==12.4.127
#  + nvidia-nvtx-cu12==12.4.127
#  + orjson==3.10.15
#  + packaging==24.2
#  + pandas==2.2.3
#  + phonemizer==3.3.0
#  + pillow==11.1.0
#  + pycparser==2.22
#  + pydantic==2.10.6
#  + pydantic-core==2.27.2
#  + pydub==0.25.1
#  + pygments==2.19.1
#  + pylatexenc==2.10
#  + pyparsing==3.2.1
#  + python-dateutil==2.9.0.post0
#  + python-multipart==0.0.20
#  + pytz==2025.1
#  + pyyaml==6.0.2
#  + rdflib==7.1.3
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + rfc3986==1.5.0
#  + rich==13.9.4
#  + rpds-py==0.22.3
#  + ruff==0.9.6
#  + safehttpx==0.1.6
#  + safetensors==0.5.2
#  + segments==2.2.1
#  + semantic-version==2.10.0
#  + setuptools==75.8.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soundfile==0.13.1
#  + starlette==0.45.3
#  + sudachidict-full==20250129
#  + sudachipy==0.6.10
#  + sympy==1.13.1
#  + tabulate==0.9.0
#  + tokenizers==0.21.0
#  + tomlkit==0.13.2
#  + torch==2.6.0
#  + torchaudio==2.6.0
#  + tqdm==4.67.1
#  + transformers==4.48.3
#  + triton==3.2.0
#  + typeguard==4.4.1
#  + typer==0.15.1
#  + typing-extensions==4.12.2
#  + tzdata==2025.1
#  + uritemplate==4.1.1
#  + urllib3==2.3.0
#  + uvicorn==0.34.0
#  + websockets==14.2
# Resolved 116 packages in 0.91ms
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)
# einops     ------------------------------ 30.89 KiB/42.21 KiB
# ⠙ Preparing packages... (0/5)
# einops     ------------------------------ 42.21 KiB/42.21 KiB
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
# einops     ------------------------------ 42.21 KiB/42.21 KiB
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
# einops     ------------------------------ 42.21 KiB/42.21 KiB
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
# ⠙ Preparing packages... (0/5)
#    Building causal-conv1d==1.5.0.post8
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#       Built causal-conv1d==1.5.0.post8
#    Building mamba-ssm==2.2.4
#    Building flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#    Building mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#       Built mamba-ssm==2.2.4
#       Built flash-attn==2.7.4.post1
#       Built flash-attn==2.7.4.post1
# Prepared 5 packages in 32.91s
# Installed 5 packages in 5ms
#  + causal-conv1d==1.5.0.post8
#  + einops==0.8.0
#  + flash-attn==2.7.4.post1
#  + mamba-ssm==2.2.4
#  + ninja==1.11.1.3

# %%
# !pip install -e .
# !pip install -e .[compile]
# !pip install gradio torch torchaudio
# Out:
# Obtaining file:///content/Zonos
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (75.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (24.2)
# Requirement already satisfied: inflect>=7.5.0 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (7.5.0)
# Collecting kanjize>=1.5.0 (from zonos==0.1.0)
#   Downloading kanjize-1.6.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting numpy>=2.2.2 (from zonos==0.1.0)
#   Downloading numpy-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.1 MB/s eta 0:00:00
# Collecting phonemizer>=3.3.0 (from zonos==0.1.0)
#   Downloading phonemizer-3.3.0-py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.4 MB/s eta 0:00:00
# Collecting sudachidict-full>=20241021 (from zonos==0.1.0)
#   Downloading SudachiDict-full-20250129.tar.gz (9.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sudachipy>=0.6.10 (from zonos==0.1.0)
#   Downloading SudachiPy-0.6.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: torchaudio>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: transformers>=4.48.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (4.48.3)
# Requirement already satisfied: soundfile>=0.13.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (0.13.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (0.28.1)
# Collecting gradio>=5.15.0 (from zonos==0.1.0)
#   Downloading gradio-5.21.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (3.7.1)
# Collecting fastapi<1.0,>=0.115.2 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading fastapi-0.115.11-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.7.2 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading gradio_client-1.7.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (3.1.6)
# Collecting markupsafe~=2.0 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (3.10.15)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (11.1.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (2.10.6)
# Collecting pydub (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading ruff-0.11.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.15.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio>=5.15.0->zonos==0.1.0)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.2->gradio>=5.15.0->zonos==0.1.0) (2024.10.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.2->gradio>=5.15.0->zonos==0.1.0) (14.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->zonos==0.1.0) (3.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->zonos==0.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->zonos==0.1.0) (4.67.1)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from inflect>=7.5.0->zonos==0.1.0) (10.6.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from inflect>=7.5.0->zonos==0.1.0) (4.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from phonemizer>=3.3.0->zonos==0.1.0) (1.4.2)
# Collecting segments (from phonemizer>=3.3.0->zonos==0.1.0)
#   Downloading segments-2.3.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: attrs>=18.1 in /usr/local/lib/python3.11/dist-packages (from phonemizer>=3.3.0->zonos==0.1.0) (25.2.0)
# Collecting dlinfo (from phonemizer>=3.3.0->zonos==0.1.0)
#   Downloading dlinfo-2.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.13.1->zonos==0.1.0) (1.17.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (3.4.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.5.1->zonos==0.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.5.1->zonos==0.1.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.1->zonos==0.1.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.1->zonos==0.1.0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.1->zonos==0.1.0) (0.5.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio>=5.15.0->zonos==0.1.0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio>=5.15.0->zonos==0.1.0) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.13.1->zonos==0.1.0) (2.22)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio>=5.15.0->zonos==0.1.0) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio>=5.15.0->zonos==0.1.0) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=5.15.0->zonos==0.1.0) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio>=5.15.0->zonos==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio>=5.15.0->zonos==0.1.0) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio>=5.15.0->zonos==0.1.0) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio>=5.15.0->zonos==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio>=5.15.0->zonos==0.1.0) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (13.9.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->zonos==0.1.0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->zonos==0.1.0) (2.3.0)
# Collecting csvw>=1.5.6 (from segments->phonemizer>=3.3.0->zonos==0.1.0)
#   Downloading csvw-3.5.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting isodate (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting rfc3986<2 (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (4.1.1)
# Requirement already satisfied: babel in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (2.17.0)
# Collecting language-tags (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0)
#   Downloading language_tags-1.2.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting rdflib (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Collecting colorama (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio>=5.15.0->zonos==0.1.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (0.1.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (0.23.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib->csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (3.2.1)
# Downloading gradio-5.21.0-py3-none-any.whl (46.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 16.8 MB/s eta 0:00:00
# Downloading gradio_client-1.7.2-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 kB 24.7 MB/s eta 0:00:00
# Downloading kanjize-1.6.0-py3-none-any.whl (6.8 kB)
# Downloading numpy-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 97.4 MB/s eta 0:00:00
# Downloading phonemizer-3.3.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 9.4 MB/s eta 0:00:00
# Downloading SudachiPy-0.6.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 77.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 101.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.7 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.11-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 9.8 MB/s eta 0:00:00
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.11.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 109.6 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.9 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.9 MB/s eta 0:00:00
# Downloading dlinfo-2.0.0-py3-none-any.whl (3.7 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading segments-2.3.0-py2.py3-none-any.whl (15 kB)
# Downloading csvw-3.5.1-py2.py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 6.3 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading language_tags-1.2.0-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.4/213.4 kB 20.5 MB/s eta 0:00:00
# Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 46.8 MB/s eta 0:00:00
# Building wheels for collected packages: zonos, sudachidict-full
#   Building editable for zonos (pyproject.toml) ... done
#   Created wheel for zonos: filename=zonos-0.1.0-0.editable-py3-none-any.whl size=9566 sha256=1100252d087f948fbb90d248448c9ea95b2457cedf9c8e2e57ad7a4c334c3683
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s561iosi/wheels/b2/89/25/42dcfe059fed151615089709657b4d54f0dbf86452175cb772
#   Building wheel for sudachidict-full (setup.py) ... done
#   Created wheel for sudachidict-full: filename=SudachiDict_full-20250129-py3-none-any.whl size=126565548 sha256=d032d3dbc1d1a7b7f3bb6973af11847e0799bf29263e49c86b3456566ae17bb9
#   Stored in directory: /root/.cache/pip/wheels/32/a2/06/e41b09b915d9df25cb3af796a171584d015650309f4cc3c3b8
# Successfully built zonos sudachidict-full
# Installing collected packages: sudachipy, rfc3986, pydub, language-tags, uvicorn, tomlkit, sudachidict-full, semantic-version, ruff, rdflib, python-multipart, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, markupsafe, kanjize, isodate, groovy, ffmpy, dlinfo, colorama, aiofiles, starlette, nvidia-cusparse-cu12, nvidia-cudnn-cu12, safehttpx, nvidia-cusolver-cu12, gradio-client, fastapi, gradio, csvw, segments, phonemizer, zonos
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.2.3 which is incompatible.
# pytensor 2.27.1 requires numpy<2,>=1.17.0, but you have numpy 2.2.3 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.3 which is incompatible.
# Successfully installed aiofiles-23.2.1 colorama-0.4.6 csvw-3.5.1 dlinfo-2.0.0 fastapi-0.115.11 ffmpy-0.5.0 gradio-5.21.0 gradio-client-1.7.2 groovy-0.1.2 isodate-0.7.2 kanjize-1.6.0 language-tags-1.2.0 markupsafe-2.1.5 numpy-2.2.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 phonemizer-3.3.0 pydub-0.25.1 python-multipart-0.0.20 rdflib-7.1.3 rfc3986-1.5.0 ruff-0.11.0 safehttpx-0.1.6 segments-2.3.0 semantic-version-2.10.0 starlette-0.46.1 sudachidict-full-20250129 sudachipy-0.6.10 tomlkit-0.13.2 uvicorn-0.34.0 zonos-0.1.0
# Obtaining file:///content/Zonos
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (75.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (24.2)
# Requirement already satisfied: inflect>=7.5.0 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (7.5.0)
# Requirement already satisfied: kanjize>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (1.6.0)
# Requirement already satisfied: numpy>=2.2.2 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (2.2.3)
# Requirement already satisfied: phonemizer>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (3.3.0)
# Requirement already satisfied: sudachidict-full>=20241021 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (20250129)
# Requirement already satisfied: sudachipy>=0.6.10 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (0.6.10)
# Requirement already satisfied: torchaudio>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: transformers>=4.48.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (4.48.3)
# Requirement already satisfied: soundfile>=0.13.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (0.13.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (0.28.1)
# Requirement already satisfied: gradio>=5.15.0 in /usr/local/lib/python3.11/dist-packages (from zonos==0.1.0) (5.21.0)
# Collecting flash-attn>=2.7.3 (from zonos==0.1.0)
#   Downloading flash_attn-2.7.4.post1.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 81.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mamba-ssm>=2.2.4 (from zonos==0.1.0)
#   Downloading mamba_ssm-2.2.4.tar.gz (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 8.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting causal-conv1d>=1.5.0.post8 (from zonos==0.1.0)
#   Downloading causal_conv1d-1.5.0.post8.tar.gz (9.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ninja (from causal-conv1d>=1.5.0.post8->zonos==0.1.0)
#   Using cached ninja-1.11.1.3-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from flash-attn>=2.7.3->zonos==0.1.0) (0.8.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (3.7.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.115.11)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.5.0)
# Requirement already satisfied: gradio-client==1.7.2 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (1.7.2)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (3.1.6)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (3.10.15)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (11.1.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (2.10.6)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.11.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.46.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.15.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=5.15.0->zonos==0.1.0) (0.34.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.2->gradio>=5.15.0->zonos==0.1.0) (2024.10.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.2->gradio>=5.15.0->zonos==0.1.0) (14.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->zonos==0.1.0) (3.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->zonos==0.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->zonos==0.1.0) (4.67.1)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from inflect>=7.5.0->zonos==0.1.0) (10.6.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from inflect>=7.5.0->zonos==0.1.0) (4.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from phonemizer>=3.3.0->zonos==0.1.0) (1.4.2)
# Requirement already satisfied: segments in /usr/local/lib/python3.11/dist-packages (from phonemizer>=3.3.0->zonos==0.1.0) (2.3.0)
# Requirement already satisfied: attrs>=18.1 in /usr/local/lib/python3.11/dist-packages (from phonemizer>=3.3.0->zonos==0.1.0) (25.2.0)
# Requirement already satisfied: dlinfo in /usr/local/lib/python3.11/dist-packages (from phonemizer>=3.3.0->zonos==0.1.0) (2.0.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.13.1->zonos==0.1.0) (1.17.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->zonos==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.5.1->zonos==0.1.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.1->zonos==0.1.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.1->zonos==0.1.0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.1->zonos==0.1.0) (0.5.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio>=5.15.0->zonos==0.1.0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio>=5.15.0->zonos==0.1.0) (1.3.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.13.1->zonos==0.1.0) (2.22)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio>=5.15.0->zonos==0.1.0) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio>=5.15.0->zonos==0.1.0) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=5.15.0->zonos==0.1.0) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio>=5.15.0->zonos==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio>=5.15.0->zonos==0.1.0) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio>=5.15.0->zonos==0.1.0) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio>=5.15.0->zonos==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio>=5.15.0->zonos==0.1.0) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (13.9.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->zonos==0.1.0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->zonos==0.1.0) (2.3.0)
# Requirement already satisfied: csvw>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from segments->phonemizer>=3.3.0->zonos==0.1.0) (3.5.1)
# Requirement already satisfied: isodate in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (0.7.2)
# Requirement already satisfied: rfc3986<2 in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (4.1.1)
# Requirement already satisfied: babel in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (2.17.0)
# Requirement already satisfied: language-tags in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (1.2.0)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (7.1.3)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (0.4.6)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio>=5.15.0->zonos==0.1.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio>=5.15.0->zonos==0.1.0) (0.1.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (0.23.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib->csvw>=1.5.6->segments->phonemizer>=3.3.0->zonos==0.1.0) (3.2.1)
# Using cached ninja-1.11.1.3-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
# Building wheels for collected packages: zonos, causal-conv1d, flash-attn, mamba-ssm
#   Building editable for zonos (pyproject.toml) ... done
#   Created wheel for zonos: filename=zonos-0.1.0-0.editable-py3-none-any.whl size=9566 sha256=b23d7792c556a2b8d8d849b01c25e75ab7539963cf70108358d6d300180fc152
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dc16q687/wheels/b2/89/25/42dcfe059fed151615089709657b4d54f0dbf86452175cb772
#   Building wheel for causal-conv1d (setup.py) ... done
#   Created wheel for causal-conv1d: filename=causal_conv1d-1.5.0.post8-cp311-cp311-linux_x86_64.whl size=103984203 sha256=f1bff4a48017e4a1b2f18a84b3d881df7de2cff8cc9dbbc0c53c9d5df233359b
#   Stored in directory: /root/.cache/pip/wheels/ba/be/7d/2b11e629de32101f0801e2c62d5a26ff09802c391561a3e3eb
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.7.4.post1-cp311-cp311-linux_x86_64.whl size=187831595 sha256=58853b28a5a926cae14402bfd8d4d93a45ebf8f9e79533f37ab09d0d77a99c05
#   Stored in directory: /root/.cache/pip/wheels/3d/88/d8/284b89f56af7d5bf366b10d6b8e251ac8a7c7bf3f04203fb4f
#   Building wheel for mamba-ssm (pyproject.toml) ... done
#   Created wheel for mamba-ssm: filename=mamba_ssm-2.2.4-cp311-cp311-linux_x86_64.whl size=323672993 sha256=8a0be01153fa30727a9e69024fbe061eb92c7ba4416d2049c5fc3107ed91d852
#   Stored in directory: /root/.cache/pip/wheels/2a/5e/64/cfcb5dfe4f854944456e031c34953dc872af1ad7c206145d4a
# Successfully built zonos causal-conv1d flash-attn mamba-ssm
# Installing collected packages: ninja, flash-attn, causal-conv1d, mamba-ssm, zonos
#   Attempting uninstall: zonos
#     Found existing installation: zonos 0.1.0
#     Uninstalling zonos-0.1.0:
#       Successfully uninstalled zonos-0.1.0
# Successfully installed causal-conv1d-1.5.0.post8 flash-attn-2.7.4.post1 mamba-ssm-2.2.4 ninja-1.11.1.3 zonos-0.1.0
# Requirement already satisfied: gradio in /usr/local/lib/python3.11/dist-packages (5.21.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.7.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.115.11)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.7.2 in /usr/local/lib/python3.11/dist-packages (from gradio) (1.7.2)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.2.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.10.15)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.10.6)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.11.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.46.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.15.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.34.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.2->gradio) (2024.10.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.7.2->gradio) (14.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.28.1->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.0->gradio) (2.27.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import os
import gradio as gr
import torch
import torchaudio
from zonos.model import Zonos
from zonos.conditioning import make_cond_dict

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = Zonos.from_pretrained("Zyphra/Zonos-v0.1-transformer", device=device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.52k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.25G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/307M [00:00<?, ?B/s]

# %%
story = {
    "start": {
        "text": (
            "You wake up in a mysterious forest. The air is cool and the silence is eerie. "
            "Shadows dance between ancient trees, and you feel as if unseen eyes are watching your every move."
        ),
        "emotion": "anxious",
        "options": [
            {"choice": "Follow the narrow path", "next": "path"},
            {"choice": "Venture off into the trees", "next": "trees"}
        ]
    },
    "path": {
        "text": (
            "You follow the narrow, winding path. As you proceed, the rustling leaves and distant creaks "
            "fill you with a growing sense of unease. Ahead, a dim light flickers in the distance."
        ),
        "emotion": "cautious",
        "options": [
            {"choice": "Investigate the light", "next": "cottage"},
            {"choice": "Keep following the path", "next": "continue_path"}
        ]
    },
    "trees": {
        "text": (
            "Disregarding the path, you dive deeper into the thick trees. A haunting melody weaves through the air, "
            "pulling you further from safety into a realm of shadows."
        ),
        "emotion": "uneasy",
        "options": [
            {"choice": "Follow the melody", "next": "melody"},
            {"choice": "Turn back toward the path", "next": "path"}
        ]
    },
    "cottage": {
        "text": (
            "You approach a quaint, weathered cottage with flickering candlelight in the window. An elderly woman "
            "stands at the door, her eyes both inviting and sorrowful."
        ),
        "emotion": "mysterious",
        "options": [
            {"choice": "Enter the cottage", "next": "stories"},
            {"choice": "Politely decline and leave", "next": "decline"}
        ]
    },
    "continue_path": {
        "text": (
            "You continue along the path, which now forks into two. One branch is overgrown and wild, while the "
            "other is disturbingly clear, as if recently traveled."
        ),
        "emotion": "apprehensive",
        "options": [
            {"choice": "Take the overgrown branch", "next": "abandoned_village"},
            {"choice": "Take the clear branch", "next": "hidden_cave"}
        ]
    },
    "melody": {
        "text": (
            "The melody leads you to a clearing where an ancient shrine looms. The air is thick with secrets, and "
            "a spectral figure lingers at the edge of your vision."
        ),
        "emotion": "haunted",
        "options": [
            {"choice": "Approach the shrine", "next": "haunted_shrine"},
            {"choice": "Confront the spectral figure", "next": "mysterious_figure"}
        ]
    },
    "stories": {
        "text": (
            "Inside the cottage, the elderly woman recounts tales of lost souls and forgotten curses that haunt this forest. "
            "Her words reveal clues of a hidden terror lurking in the shadows."
        ),
        "emotion": "foreboding",
        "options": [
            {"choice": "Investigate further based on her clues", "next": "secret_revelation"},
            {"choice": "Leave the cottage in fear", "next": "decline"}
        ]
    },
    "decline": {
        "text": (
            "You decide not to trust the ominous signs. As you step away, the forest seems to close in around you, "
            "and you realize you may have lost your way."
        ),
        "emotion": "desperate",
        "options": [
            {"choice": "Try to find a way out", "next": "lost_in_darkness"},
            {"choice": "Return to the path", "next": "path"}
        ]
    },
    "left_fork": {
        "text": (
            "You take the left fork, and the forest darkens unnaturally. Every rustle and whisper sends shivers down your spine, "
            "as if something sinister stalks your every step."
        ),
        "emotion": "terrified",
        "options": [
            {"choice": "Press on despite the fear", "next": "sinister_shadow"},
            {"choice": "Turn back immediately", "next": "decline"}
        ]
    },
    "right_fork": {
        "text": (
            "You choose the right fork, where the trees part to reveal a brief, clear sky. Yet, a feeling of false hope fills you; "
            "the calm appears too contrived."
        ),
        "emotion": "suspicious",
        "options": [
            {"choice": "Investigate the clearing", "next": "final_escape"},
            {"choice": "Ignore it and continue", "next": "left_fork"}
        ]
    },
    "abandoned_village": {
        "text": (
            "The overgrown branch leads you to the ruins of an abandoned village. Crumbling houses and faded relics whisper of a tragic past, "
            "while an eerie silence pervades the area."
        ),
        "emotion": "somber",
        "options": [
            {"choice": "Search the village for clues", "next": "secret_revelation"},
            {"choice": "Quickly leave the village", "next": "continue_path"}
        ]
    },
    "hidden_cave": {
        "text": (
            "Taking the clear branch, you discover a hidden cave entrance veiled by ivy. A cold breeze from within hints at "
            "frozen memories and long-forgotten terrors."
        ),
        "emotion": "curious",
        "options": [
            {"choice": "Enter the cave", "next": "final_confrontation"},
            {"choice": "Retreat and take the other branch", "next": "abandoned_village"}
        ]
    },
    "haunted_shrine": {
        "text": (
            "At the shrine, ghostly chants echo amid the still air. An altar, adorned with cryptic symbols and withered offerings, "
            "implies that disturbing forces are at work."
        ),
        "emotion": "ominous",
        "options": [
            {"choice": "Attempt to decipher the symbols", "next": "secret_revelation"},
            {"choice": "Flee the shrine immediately", "next": "decline"}
        ]
    },
    "mysterious_figure": {
        "text": (
            "The spectral figure approaches, its face shrouded in mist. It gestures silently as if pleading for help, yet its eyes "
            "reveal centuries of sorrow and warning."
        ),
        "emotion": "melancholic",
        "options": [
            {"choice": "Follow the figure", "next": "secret_revelation"},
            {"choice": "Resist and run away", "next": "lost_in_darkness"}
        ]
    },
    "secret_revelation": {
        "text": (
            "Piecing together the clues, you uncover a horrifying secret: the forest is a nexus of restless spirits, bound by an "
            "ancient, malevolent curse. The revelation sends chills coursing through your veins."
        ),
        "emotion": "shocked",
        "options": [
            {"choice": "Decide to break the curse", "next": "final_confrontation"},
            {"choice": "Flee in terror", "next": "lost_in_darkness"}
        ]
    },
    "lost_in_darkness": {
        "text": (
            "You wander aimlessly as the forest transforms into a labyrinth of twisting paths and suffocating darkness. Every step "
            "feels like a descent into madness."
        ),
        "emotion": "panic",
        "options": [
            {"choice": "Try to recall the clues from earlier", "next": "secret_revelation"},
            {"choice": "Surrender to despair", "next": "decline"}
        ]
    },
    "sinister_shadow": {
        "text": (
            "As you press on, a sinister shadow materializes behind you, growing larger and more menacing with every heartbeat. "
            "Its overwhelming presence leaves you paralyzed with fear."
        ),
        "emotion": "horrified",
        "options": [
            {"choice": "Stand your ground and confront it", "next": "final_confrontation"},
            {"choice": "Run as fast as you can", "next": "lost_in_darkness"}
        ]
    },
    "final_escape": {
        "text": (
            "In a desperate bid for freedom, you dash toward the clearing. The forest seems to part before you, offering a fleeting "
            "escape from the encroaching terror."
        ),
        "emotion": "relieved",
        "options": [
            {"choice": "Run without looking back", "next": "final_confrontation"},
            {"choice": "Slow down and search for any signs of help", "next": "secret_revelation"}
        ]
    },
    "final_confrontation": {
        "text": (
            "The moment of truth arrives as you confront the malevolent force head-on. In the heart of the cursed forest, "
            "a fierce battle of wills ensues—your very soul hangs in the balance."
        ),
        "emotion": "determined",
        "options": [
            {"choice": "Use the power of your revelation to break the curse", "next": "final_escape"},
            {"choice": "Succumb to the darkness", "next": "lost_in_darkness"}
        ]
    }
}

# %%
import math
import os
import torchaudio.sox_effects as sox_effects

def generate_tts_audio(text, voice_sample_path, emotion="neutral", language="en-us",
                       speaking_rate=1.0, pitch=1.0):


    print(f"Generating TTS audio for text: {text}")
    wav, sr = torchaudio.load(voice_sample_path)
    speaker = model.make_speaker_embedding(wav, sr)

    cond_dict = make_cond_dict(
        text=text,
        speaker=speaker,
        language=language
    )

    conditioning = model.prepare_conditioning(cond_dict)
    codes = model.generate(conditioning)
    wavs = model.autoencoder.decode(codes).cpu()

    effects = []
    if speaking_rate != 1.0:
        effects.append(["tempo", str(speaking_rate)])
    if pitch != 1.0:
        semitones = 12 * math.log2(pitch)
        effects.append(["pitch", f"{semitones:.2f}"])
        effects.append(["rate", str(sr)])

    if effects:
        wavs_transformed, _ = sox_effects.apply_effects_tensor(wavs[0].unsqueeze(0), sr, effects)
        wav_final = wavs_transformed.squeeze(0)
    else:
        wav_final = wavs[0]

    segment_path = "new_segment.wav"
    torchaudio.save(segment_path, wav_final, sr)

    cumulative_path = "generated_audio.wav"
    if os.path.exists(cumulative_path):
        existing_audio, existing_sr = torchaudio.load(cumulative_path)
        if existing_sr != sr:
            print("Sample rate mismatch detected. Overwriting existing file.")
            combined = wav_final
        else:
            combined = torch.cat([existing_audio, wav_final], dim=1)
    else:
        combined = wav_final

    torchaudio.save(cumulative_path, combined, sr)
    print(f"Segment saved to {segment_path} and cumulative audio updated in {cumulative_path}")

    return segment_path, cumulative_path

# %%
def advance_story(choice_index, current_node_id, voice_sample_path, speaking_rate, pitch):
    if choice_index == -1:
        return "Story ended. Here is the full audio of your adventure.", current_node_id, [], "generated_audio.wav"

    current_node = story.get(current_node_id)
    if not current_node:
        return "Error: Current node not found.", current_node_id, [], ""

    options = current_node.get("options", [])

    if choice_index < 0 or choice_index >= len(options):
        return "Invalid choice selected.", current_node_id, options, ""

    next_node_id = options[choice_index]["next"]
    next_node = story.get(next_node_id)
    if not next_node:
        return "End of story reached.", current_node_id, [], "generated_audio.wav"

    next_text = next_node.get("text", "")
    next_emotion = next_node.get("emotion", "neutral")

    segment_audio, cumulative_audio = generate_tts_audio(
        text=next_text,
        voice_sample_path=voice_sample_path,
        emotion=next_emotion,
        speaking_rate=speaking_rate,
        pitch=pitch
    )

    next_options = [opt["choice"] for opt in next_node.get("options", [])]
    return next_text, next_node_id, next_options, segment_audio

# %%
def start_story(voice_sample_path, speaking_rate, pitch):
    current_node_id = "start"
    node = story.get(current_node_id)
    text = node.get("text", "")
    emotion = node.get("emotion", "neutral")

    segment_audio, cumulative_audio = generate_tts_audio(
        text=text,
        voice_sample_path=voice_sample_path,
        emotion=emotion,
        speaking_rate=speaking_rate,
        pitch=pitch
    )
    options = [opt["choice"] for opt in node.get("options", [])]
    return text, current_node_id, options, segment_audio

# %%
import gradio as gr

with gr.Blocks() as demo:
    gr.Markdown("## VoxVoyage: Crafting Your Adventures with Every Word")

    with gr.Row():
        voice_sample_input = gr.File(label="Upload Voice Sample (for voice cloning)", file_types=["audio"])
        speaking_rate_slider = gr.Slider(minimum=0.5, maximum=2.0, value=1.0, step=0.1, label="Speaking Rate")
        pitch_slider = gr.Slider(minimum=0.5, maximum=2.0, value=1.0, step=0.1, label="Pitch")

    with gr.Row():
        start_button = gr.Button("Start Story")
        advance_button = gr.Button("Advance Story")
        quit_button = gr.Button("Quit Story")

    story_text = gr.Textbox(label="Story Narrative", interactive=False, lines=4)
    options_radio = gr.Radio(choices=[], label="Choose an Option")
    audio_output = gr.Audio(label="Generated Speech", type="filepath")

    current_node_state = gr.State("start")

    def start_callback(voice_file, speaking_rate, pitch):
        if voice_file is None:
            return "Please upload a voice sample to start the story.", "start", gr.update(choices=[]), ""
        voice_path = voice_file["name"] if isinstance(voice_file, dict) else voice_file
        text, node_id, options, segment_audio = start_story(voice_path, speaking_rate, pitch)
        radio_update = gr.update(choices=options, value=options[0] if options else None)
        return text, node_id, radio_update, segment_audio

    start_button.click(
        start_callback,
        inputs=[voice_sample_input, speaking_rate_slider, pitch_slider],
        outputs=[story_text, current_node_state, options_radio, audio_output]
    )

    def advance_callback(choice, current_node, voice_file, speaking_rate, pitch):
        if voice_file is None:
            return "Please upload a voice sample.", current_node, gr.update(choices=[]), ""
        voice_path = voice_file["name"] if isinstance(voice_file, dict) else voice_file
        try:
            choice_index = int(choice)
        except Exception as e:
            choice_index = 0
        text, new_node, options, segment_audio = advance_story(choice_index, current_node, voice_path, speaking_rate, pitch)
        radio_update = gr.update(choices=options, value=options[0] if options else None)
        return text, new_node, radio_update, segment_audio

    advance_button.click(
        advance_callback,
        inputs=[options_radio, current_node_state, voice_sample_input, speaking_rate_slider, pitch_slider],
        outputs=[story_text, current_node_state, options_radio, audio_output]
    )

    def quit_callback(current_node, voice_file, speaking_rate, pitch):
        if voice_file is None:
            return "Please upload a voice sample.", current_node, gr.update(choices=[]), ""
        voice_path = voice_file["name"] if isinstance(voice_file, dict) else voice_file
        text, new_node, options, audio = advance_story(-1, current_node, voice_path, speaking_rate, pitch)
        radio_update = gr.update(choices=options, value=None)
        return text, new_node, radio_update, audio

    quit_button.click(
        quit_callback,
        inputs=[current_node_state, voice_sample_input, speaking_rate_slider, pitch_slider],
        outputs=[story_text, current_node_state, options_radio, audio_output]
    )

# %%
demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://70f1eb64b0d0f37106.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://70f1eb64b0d0f37106.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
